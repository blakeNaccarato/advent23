# %% [markdown]
# # Day 1

# %% [markdown]
# ## Part 1: Trebuchet?!
#
# Something is wrong with global snow production, and you've been selected to take a look. The Elves have even given you a map; on it, they've used stars to mark the top fifty locations that are likely to be having problems.
#
# You've been doing this long enough to know that to restore snow operations, you need to check all **fifty stars** by December 25th.
#
# Collect stars by solving puzzles. Two puzzles will be made available on each day in the Advent calendar; the second puzzle is unlocked when you complete the first. Each puzzle grants **one star**. Good luck!
#
# You try to ask why they can't just use a **weather machine** ("not powerful enough") and where they're even sending you ("the sky") and why your map looks mostly blank ("you sure ask a lot of questions") and hang on did you just say the sky ("of course, where do you think snow comes from") when you realize that the Elves are already loading you into a **trebuchet** ("please hold still, we need to strap you in").
#
# As they're making the final adjustments, they discover that their calibration document (your puzzle input) has been amended by a very young Elf who was apparently just excited to show off her art skills. Consequently, the Elves are having trouble reading the values on the document.
#
# The newly-improved calibration document consists of lines of text; each line originally contained a specific **calibration value** that the Elves now need to recover. On each line, the calibration value can be found by combining the **first digit** and the **last digit** (in that order) to form a single **two-digit number**.
#
# For example:
#
# ```Plaintext
# 1abc2
# pqr3stu8vwx
# a1b2c3d4e5f
# treb7uchet
# ```
#
# In this example, the calibration values of these four lines are `12`, `38`, `15`, and `77`. Adding these together produces `142`.
#
# Consider your entire calibration document. **What is the sum of all of the calibration values?**

# %%
import re
from pathlib import Path

import pandas as pd

INPUT = """\
1abc2
pqr3stu8vwx
a1b2c3d4e5f
treb7uchet
"""

# %%
with Path("input/abdul/day01.txt").open() as file:
    ans = 0
    for line in file.readlines():
        line_num_list = re.findall("[0-9]", repr(line))
        extracted_num = line_num_list[0] + line_num_list[-1]
        ans += int(extracted_num)


OUTPUT = ans
display(OUTPUT)
# Out:
# 54338

# %% [markdown]
# <article class="day-desc"><h2 id="part2">Part 2</h2><p>Your calculation isn't quite right. It looks like some of the digits are actually <em>spelled out with letters</em>: <code>one</code>, <code>two</code>, <code>three</code>, <code>four</code>, <code>five</code>, <code>six</code>, <code>seven</code>, <code>eight</code>, and <code>nine</code> <em>also</em> count as valid "digits".</p>
# <p>Equipped with this new information, you now need to find the real first and last digit on each line. For example:</p>
# <pre><code>two1nine
# eightwothree
# abcone2threexyz
# xtwone3four
# 4nineeightseven2
# zoneight234
# 7pqrstsixteen
# </code></pre>
# <p>In this example, the calibration values are <code>29</code>, <code>83</code>, <code>13</code>, <code>24</code>, <code>42</code>, <code>14</code>, and <code>76</code>. Adding these together produces <code><em>281</em></code>.</p>
# <p><em>What is the sum of all of the calibration values?</em></p>

# %%
# Find positions where sub-strings exist and replace based off of position value

number_map = {
    "zero": "0xxx",
    "one": "1xx",
    "two": "2xx",
    "three": "3xxxx",
    "four": "4xxx",
    "five": "5xxx",
    "six": "6xx",
    "seven": "7xxxx",
    "eight": "8xxxx",
    "nine": "9xxx",
}


with Path("input/abdul/day01.txt").open() as file:
    ans = 0
    for line in file.readlines():
        df = pd.DataFrame(columns=list(range(len(line))))
        for key in number_map:
            unpacked_line = [*line.replace(key, str(number_map[key]))]
            df.loc[len(df.index)] = pd.Series(unpacked_line)

        mapped_string = ""
        for column in df.columns:
            mapped_string += df.sort_values(by=column, ascending=True).iloc[0, column]

        # Implement old part01 logic after words converted to digits
        line_num_list = re.findall("[0-9]", repr(mapped_string))
        extracted_num = line_num_list[0] + line_num_list[-1]
        print(f"{mapped_string}{extracted_num}\n")
        ans += int(extracted_num)

OUTPUT = ans
display(OUTPUT)
# Out:
# 29113hree9inesdvxvh8igh2wobm
# 22
#
# 33hree16xsxhpnqmzm9ine81ne
# 31
#
# 7even5kh2wo891hlb
# 71
#
# 6ix3hreeqpzjpn195
# 65
#
# jrnf3
# 33
#
# qpzcfbfsrx3hree9ine3ksbghzzff7even5ive9
# 39
#
# 2fxvxzzgdnfkzzh48ight9ine75ive
# 25
#
# 44our2wobjscjgtbv9ine6ix
# 46
#
# 1ne2wo5ivelvnbcbn5
# 15
#
# 6vjdtd1j18ight1ne
# 61
#
# sshnxbjrt1
# 11
#
# 5ljsxqjdxr91
# 51
#
# 716ix14rkdhdszbfz
# 74
#
# khlm3
# 33
#
# jnsjhqqtj64ourslpqntdzxp5ive
# 65
#
# 68ightp
# 68
#
# qtqrcs6gdqmtzn9inexvpnrn
# 69
#
# 7evenrcdbnzfltt47even3nz6ix3hreeszr
# 73
#
# 1ne4our96qtffc
# 16
#
# klpksqsggbrf5ive1tdsfptnvs72
# 52
#
# lsx3qrmznjrfnvvzv8ight51ne
# 31
#
# dqlrxck24ourkp62wo464
# 24
#
# 59iner3kcdsxq4our8ight5ive
# 55
#
# lq2wo77evensvghmsdjzbbdrhqjg4
# 24
#
# xx2wo25
# 25
#
# 6ix6zxs84our82wo
# 62
#
# 4our75ive3mcmhxxtm6
# 46
#
# 1neqdkmbvvnmf643hree57
# 17
#
# 94ourjgmhcnpjfhtm
# 94
#
# 3lzjfv3hree7evenzlbgpcslvrpglq7even
# 37
#
# 68ight1
# 61
#
# xxcgtrqzcjj2wo6ix79inejzzsg3
# 23
#
# 1cqx6ix
# 16
#
# 5tjmqldj6ix7even4our4fxxgsbjbxrffvzbxd
# 54
#
# 9ine2mpcplqktt
# 92
#
# rldf798ight1nedfjvkvjjx
# 71
#
# 35ive8ight1n8ightg
# 38
#
# 956ix43hree
# 93
#
# kfn4871ne1ne1mckljv3
# 43
#
# 24our6lcbv9inezscnjjz2wo32wo
# 22
#
# 4697even6ix3hree
# 43
#
# vqvjll17even784our
# 14
#
# 1fmstxpg9
# 19
#
# 1nefxtvjhxmfbgmf13hree
# 13
#
# 3hree5ive6ix81nebxpdfkxddkdxnt
# 31
#
# 9inevkcxflcfhqx664
# 94
#
# 3283hreexc41ne2wo7
# 37
#
# 9ine51
# 91
#
# 3hree4our8ightv2
# 32
#
# 6ix58jsq69
# 69
#
# 63gzvt7even38ightmnbrmtkt7even3hree
# 63
#
# 31nepszzgskhjl61ne8ight
# 38
#
# llrrxkmrvz23hree53
# 23
#
# 7even7evenvtqdnvf7qhjt1
# 71
#
# 538ightkfrrtvsq
# 58
#
# 9inefxltvtgmrlhhdkbtb7evendrpgrcrq32wo
# 92
#
# m5hxxkg1neqfgmhndbdslvrjrnk55ive
# 55
#
# 4ourf91ne3bzljjkdl
# 43
#
# 7drfddqr4gz3hree4our
# 74
#
# 7even619ine3hreeln
# 73
#
# 3spm3hreeltlkfmcdvlfxvbnlmgsnsqskh35ive
# 35
#
# k939ine
# 99
#
# jpbdrbvtpgzlfnqz4our5ive79tmnhdm62wo
# 42
#
# dfqg4ghxvnrzstd44our52hzqkdpkdnb
# 42
#
# 85d6ix7evenmpcclxdjvsvppkpflhxqvgsjnbsvlcgv
# 87
#
# 3hreecvfdcnx4our6ix8xjzcdtb9ine
# 39
#
# rgcxrc99ine8igh2woxcb
# 92
#
# 3hree72
# 32
#
# tpfrhlnkdp2wo9vgqvdgfqdg99inemrz8ight
# 28
#
# 82wonqf5ivelnlmpgm2wo9ine
# 89
#
# snqgdxsczh59ine8ight3hreezqxmptlss97even
# 57
#
# zvsmmlgt8mzlhvbfftqnn67even5ive
# 85
#
# vfvdxfx14our7even3194
# 14
#
# 8j71psdplqssbhvxhbxz5ive5ive
# 85
#
# dhbtmxvfjjkdkdvr6
# 66
#
# mnkhzskx1ne1ne8ight7even3hree7even3
# 13
#
# 7evenzzrt3vfcsxmqgh4
# 74
#
# nbkxmzzcxtpqzvt9inevfc8ight3tjqzsbq
# 93
#
# j2
# 22
#
# 4our53lz
# 43
#
# jkrxvxl7pfq
# 77
#
# bkfvvnrqsqfrmbz4our9ine9
# 49
#
# 8ight1nekgcgdpvqksthf9
# 89
#
# jqs8ightfbdqxzllfrnnth4
# 84
#
# 2gfhfpvqzs6vhcvjlrc7even1ne
# 21
#
# 782worxggpzr
# 72
#
# kst88ightsvvfzbl3hree3hree
# 83
#
# 633hree9clsnvmkd
# 69
#
# 2nfrb95hsrcqcnrvlqtnt
# 25
#
# 717evendm2wotdvz
# 72
#
# kzkjqs7even6gqdkt
# 76
#
# 7even7eventjsvj6ix6fnggzkv9ine
# 79
#
# 262
# 22
#
# 53712wo9ine25ive2w1nepb
# 51
#
# 7g
# 77
#
# 8ight8ight9
# 89
#
# 5xfjm
# 55
#
# txh9inezhplccmvkj2
# 92
#
# dzxgmrjz3hreedxtq3hreecrkqgqh3hree8
# 38
#
# 9vngn
# 99
#
# 5mngdkpp6ix9mtxzxjlmfz91ne
# 51
#
# 67even53hree7even87even
# 67
#
# 9dxpznmpjv38ight6ix
# 96
#
# 64our7evenx
# 67
#
# 2wo7even1
# 21
#
# 5ive18ightfqgbmtz1ne
# 51
#
# fgl4247even
# 47
#
# 7177fvc8rkdptr4our
# 74
#
# 66ixbbhp89
# 69
#
# 4our82wovpkrtnshh1ne5zfnpvfdl
# 45
#
# 43hreebmrpbhrnfpn
# 43
#
# 3hree2vrxztxn4xt11ne
# 31
#
# 3hree2wo71
# 31
#
# 5ive2wo66ixzfzxbgq8ighttq4our
# 54
#
# hbbgfhrqvxpq4our3hree41
# 41
#
# 1ne8ight3xqlvnb56d2wo
# 12
#
# 6662wo8
# 68
#
# 24kgvqpqtngmlrtfmqfqprvrxzqsxjf4our5rvffnntblhnr
# 25
#
# dhmhrdn2wo6
# 26
#
# grkqnbf8ight7evenjpvqmhmbxljrlth6ix3hree5czqlcvm
# 85
#
# 8ightnjbjnpl63hree
# 83
#
# dxs2w1ne7evenbqtqpjs55ive
# 25
#
# 8ightgrbmm9ine7
# 87
#
# 11ne9
# 19
#
# bqhbdkf39ine
# 39
#
# 6ixjbckxghxr5xh
# 65
#
# 5ivespsvx355ive
# 55
#
# 54our6ix9inedl6
# 56
#
# xcbgsjh6ix33hreelbntcllhdjvqg1ne
# 61
#
# 7even2wo1
# 71
#
# rdfqxlh86ixcqkn6ix11ne3hree
# 83
#
# 9b7sdpqsg5gn
# 95
#
# 3hree2wo4our5ive65ives5ive
# 35
#
# k7
# 77
#
# mzh3hreerlrmfhzzlgzclmngn57evenlxqnbq7
# 37
#
# 17even9621
# 11
#
# 4ourvgrmxqkfqtb5ivelvm312nsdjjhqcqs
# 42
#
# fv9ine8
# 98
#
# 4ourpcvmdzbz6ix7bqdffvsgvd
# 47
#
# 513hree1nemlccggqsxq3hree
# 53
#
# 149ine5rrzf7even39ine
# 19
#
# gcq3nkkgdjlcdmjvrp3hree7
# 37
#
# 7evenh4grcmgl
# 74
#
# shjjpzcrljpmf7even9ine4
# 74
#
# 5ive17evendpjthd1
# 51
#
# dncxsx3drbllpfxp75chrvhvbblsnrxshssjxvztljmqgb
# 35
#
# bkrhmrbqtzznhzdt5ccnlxvnlvsdnsk
# 55
#
# 3drxdrxsclrpt
# 33
#
# 78ight6ix
# 76
#
# 4ourhdbsgsj796ix
# 46
#
# 55ive8ight9ine6ix8ightm44
# 54
#
# 4our25ive4rjnth3s1ne
# 41
#
# 3hree6ix7even3
# 33
#
# 1ne9ine453hree
# 13
#
# 9ine2qcrgnphbmnkr1ne6ix
# 96
#
# dsmbgbhgrv1ne768bvlznv5ive6ix9ine
# 19
#
# 4our23hree9
# 49
#
# 661ne6ix
# 66
#
# fhtqmgrz22lhqrhngrjd7
# 27
#
# 85ive1ne2wovd51nembnqk
# 81
#
# spzzrkdf2
# 22
#
# 92cgtsx9ine6ix8ight3hree
# 93
#
# 41n12wo8bfrnqclvrxghmbtdtskv
# 48
#
# mgmqskkcgf4zrttjstmfs9ineggdnbbvn4our78ight
# 48
#
# 7evenjpdbdqh9cxvvzgbhtzntn59
# 79
#
# ljh344our1nem1nerk
# 31
#
# 681ne6271
# 61
#
# 5sffblcpghqvqx5ive79inev
# 59
#
# 9ine8ight6bzvsdcks
# 96
#
# 5ndsk4
# 54
#
# v6ix52wo7evendv2
# 62
#
# 4dvvtzjvcxr38ight52wo
# 42
#
# bmzrnv8ight3hree7even6ix6ixbfplfcx35ive
# 85
#
# 5tmkgbdrj
# 55
#
# 91tnkfc1neb
# 91
#
# cvfrdpkqtmbcrrzfz4v59cvglzjx7even
# 47
#
# 75ive6pz
# 76
#
# 4svjpkzv6
# 46
#
# 64766ixq4
# 64
#
# 3f
# 33
#
# 1qlbcrdgg
# 11
#
# 9dzrjgr
# 99
#
# spcsbjmfdlqnqdx3hree4ourdhpzzqkcxl4our2
# 32
#
# 8ight78ight145cmllsqfhj
# 85
#
# 7lb73mfhnhflp
# 73
#
# 27even5ive
# 25
#
# kxgtbtc4our72wotdsj
# 42
#
# 8ight72bcb2wohtjjdcpprfldgl6ix
# 86
#
# 8ightgjrxptfdsvcpj9ine77even6ixfrbnkdxl
# 86
#
# 1ne5ive3bfdtfnjkhdsrz3hree4our
# 14
#
# xn7evenxxgckdztxf6289ine
# 79
#
# 2qfq
# 22
#
# nbxd75hrdqnm5ive21nenlchjf1n8ightlh
# 78
#
# 67even2wo5iveqfscgschrpjp2
# 62
#
# sk8igh2wo5ive4
# 84
#
# 5bfjpsmdl
# 55
#
# tjdnlshngvsnrbvmch69tqnslrhmk3hree
# 63
#
# 56ix5ive7even19ine9ine1nec
# 51
#
# 26xclfjhbxpl7even
# 27
#
# 1ne1neh24229
# 19
#
# 2wo572wolpc9ine83hree
# 23
#
# nznzdxxvrq9ine7evenrphxk48tmsj7
# 97
#
# 3hreelctkpmbkp38
# 38
#
# 8ight6ix3hreepvxxntfqdcsx2
# 82
#
# nrzg43hree1sdggv92wo
# 42
#
# 3c2cgglrzk
# 32
#
# ktbzmhmtx56ixglkfnf7even7
# 57
#
# 4plzqdl2woptkndtbxpt7
# 47
#
# 4ourrzcxbkpx3hree84our
# 44
#
# 9ine9ccsgftlfxpgvgt
# 99
#
# 15ive3
# 13
#
# 2wo9fhprhfkkljvgfgfgftskpndhqxtrnfxsnd4ourzbrrl9
# 29
#
# 59svdgrxzsxgqdvhhz2wo
# 52
#
# 7even6ix833
# 73
#
# 45
# 45
#
# 5gnjc4our3h3hree
# 53
#
# 53hree47
# 57
#
# 9ine46ix8
# 98
#
# 2wo847evenmdjcvqfmjtq9ine52wo
# 22
#
# 7dlrvr7jgftqp
# 77
#
# 1nehgxf9
# 19
#
# 5ive7131ne6ixs1ne
# 51
#
# 63hreelpch1ne69ine1ne
# 61
#
# qhclhsnlgh9ine7even3
# 93
#
# psgqpnbdhtj68ight2vgmbbrrzhtfxqvjxzrrdfrmvs
# 62
#
# qm67krpfgpqjtg5ivesmjtbhfddrbvbxtnnhj4
# 64
#
# 5ive2wo46ix
# 56
#
# spfxkx56ix5
# 55
#
# 1ne3pcmp1nehgcqqkrbplzb5ive7evenhdzfcsl
# 17
#
# dsgklz2wo358ight5gzqtrckskgspkbcz
# 25
#
# 8ight82wo1ne2wo2wo725ive
# 85
#
# 95iveqhhbml
# 95
#
# p15ive6qsgjvmmqdkjspn
# 16
#
# 93hree16
# 96
#
# tntlhjmb8ngngvrsqtfdhghbkxt
# 88
#
# 5483
# 53
#
# 4our795ivexgkjfs2
# 42
#
# 29ine2wo6tpknmfrpp9
# 29
#
# 22ncgnnmlfxg6ixprr6fzrbzznsvzcn
# 26
#
# chzbgzh7
# 77
#
# 3hree6ixhfptmhfrjlgkxj49ine1ne
# 31
#
# 7914
# 74
#
# 16ix27even2wo
# 12
#
# 341ne165ive
# 35
#
# tgrlhbnq782wodbrspdkkpbrt2wo3
# 73
#
# 5iveltsrqkqcfx99ine4756ixvzbng
# 56
#
# npdbn5ive9inetmlk4lqnskpllrqbzlvb6
# 56
#
# vf8igh2wohkppsbxf2
# 82
#
# 6qvmprfhnfs
# 66
#
# chcdrrkstnsmsrvjbqk18ight2wod1
# 11
#
# xjgsvj9dvnthx
# 99
#
# sh6ix67evenhhqdvg6ixszz9
# 69
#
# xjqzfh6ixfhvdpxpgp72wo4our
# 64
#
# vcsdm48tkmkt6snpdtsfbtpbchds
# 46
#
# 3nffrsqkv7
# 37
#
# 2jbrtfddhskblnxqxzrdbkzfkpkxdtcgxsd14
# 24
#
# 2wo77734our7even5iveggcgc
# 25
#
# 8ight1ne28ightkzpmrbjcr7spnhdkx
# 87
#
# 74our17even
# 77
#
# mbcrsht8hnbkmkx3hree3hree5ive
# 85
#
# zlckddkg43hree1nekslt
# 41
#
# dtdbkcjlmmlppghbg14ourfgkr6ix6nvkrxb9ine
# 19
#
# 412rxhqkjrqpc8ight4qdzv
# 44
#
# 8ight2wo5
# 85
#
# ljtlkbss2wo1nebbnzkxrlh6ix6ix57
# 27
#
# 8ightbrmhfc6z8ight328jmtpnt
# 88
#
# 44ourvxmrmrb22wo
# 42
#
# 3hree1ne1txqngsx21zr7even
# 37
#
# 1kpsggqxvzmrc7even5ive3hree
# 13
#
# 9lzlzlcdmcnr2wo4our7even
# 97
#
# 4our4lbvcxmxf29
# 49
#
# 69inezkhhjj
# 69
#
# bngdjjdxnndzhnp5ive2wo17
# 57
#
# blhsbxzvtncpz4our821ne91n8ightfzj
# 48
#
# cqqlvkdsf531rnvzzldbtzssxb7njhfdvc7
# 57
#
# 6ix56ix6ixblmnhrkx76
# 66
#
# 4our5zhscnznq3fvdgbmpvtx5
# 45
#
# 9z1neghtsgnkn8blxcmf14our6
# 96
#
# 3hreegtjft3hree5ive19ine4
# 34
#
# 855ndhrqsvsnk2wofphv
# 82
#
# fkfbsrvk6ix6ixs6ix2
# 62
#
# 5ive19sjvfzgrb7nhzmzfsbxbrdknvsq6
# 56
#
# 2woqfhc45ive
# 25
#
# sndnrlkfjqgpnn97evenm
# 97
#
# bphx1cvcvdghrbbhjdzp2wo
# 12
#
# gx3hree46lbltzmv6
# 36
#
# 4our2wo37even
# 47
#
# 48qfgnmnz7even1ne44our9ine4our
# 44
#
# xfz2wo4pbxxnzst2wo
# 22
#
# jgmzslhmfkpxkfssxh2rptkvfplhldprdqmhxgdqqdpb
# 22
#
# jfzpsxzq1
# 11
#
# 3vjtbd2wozdgjthqrhbcpbcjvtqbpcstqmqrmd6
# 36
#
# 8ightv23hree48igh2wobgq
# 82
#
# 12jmqnmndzvnvjzcrmphnjvhnv
# 12
#
# 1nelnfnxj66ix
# 16
#
# 3hree723thxk63
# 33
#
# 5nz6ix5d
# 55
#
# 7even2zpsfzbfjcmb7even1ne7nhv
# 77
#
# 7evenjlx32wo8ight
# 78
#
# kt2w1ne223
# 23
#
# 1hnlbcvnkj94our
# 14
#
# 68ight3snlrnvfc2wo
# 62
#
# lfndkjtnpd12wo9ine
# 19
#
# xqlc6
# 66
#
# fdtgb9gptnkvh577evenmtffxlc5
# 95
#
# 3hree37even48
# 38
#
# 654
# 64
#
# 466fzklq4our2wo3hree9inejhjgnqbnb
# 49
#
# gx31ne4our4our3hree6
# 36
#
# 71ne681neff
# 71
#
# 1529ine9inerpmkpv26
# 16
#
# ddf5
# 55
#
# krqlzrcq4our2
# 42
#
# 6ix95ive1nechvqncsdgmvjkpgdvjdt8
# 68
#
# 6ixhmhvkrzps4our64
# 64
#
# 3hree8ight82szcq8ight
# 38
#
# kr45ive5qvndccc1nerjcbnvshmlf7even
# 47
#
# 36ixczm8igh2womth
# 32
#
# 2woccnbqmnxlj61neb
# 21
#
# 8ight6ix317
# 87
#
# dnhccx8ight5ive72wo
# 82
#
# 2hpqccrxff1necrphsxttnxgnm9ineqq1ne1
# 21
#
# 7969ineggdh5ive2wocfdxq
# 72
#
# 37bqzxkpht6gshfstzdztchjrqmsdlz
# 36
#
# 9kphm3hree9
# 99
#
# 3451ne8ight
# 38
#
# x988ight1ne38fx
# 98
#
# 7692wo
# 72
#
# hplrjxbvcbt2
# 22
#
# 749inetfqdtbdspj9ine4our1nepqdh5ive
# 75
#
# 92wo1qxmrgfg66mlvkl
# 96
#
# srjllh9inecttnqj5
# 95
#
# 6cxmnhlrkxd2wo7hd3kqpd8
# 68
#
# 9ine651xctjzpbdpb23ltn
# 93
#
# 8ightktvrj85ivel
# 85
#
# 7hcx9inesrcbdrmjzbvdrxmn4our
# 74
#
# 6ixltkxmhcvxv9pxstctcvgrfsrhdxq6ix
# 66
#
# kscjlfm7even3hree2ht6ixlpbvb
# 76
#
# 5bcbhkh85ivetffq
# 55
#
# bsslrpbkgk48ight1vcb
# 41
#
# 635iverzg2534our
# 64
#
# 67even58ight
# 68
#
# 9ine6ix2wo8
# 98
#
# 2wod527even
# 27
#
# 52fs5
# 55
#
# 4our9ine5qsc5vrvbzzkxql3hree
# 43
#
# 66ix5ive
# 65
#
# tnbqgfmjgglnhqd4gndbb94our
# 44
#
# 7even37gmkmdqmkggrvkdzldg6ix2hk
# 72
#
# 11ne755ive4
# 14
#
# 1nellgpqghhmsnddnhgthk24our
# 14
#
# 1ne5bq9inelpckjbtg
# 19
#
# lqbssxxghpczz17evenrrghrncbj4ourhdcsns5
# 15
#
# t34our7even9ine59ine9
# 39
#
# 95ive4ourndphjnsvxzqgfqg6
# 96
#
# 5ivekqpfhbt3hreeqvcmblsxhp3hree6ix9ine49ine
# 59
#
# 198ightghgzbkv3xlrqncmcg
# 13
#
# 5ive65ivepmjlhgdmpjvnjjpzzqctgrr
# 55
#
# 8ightstdlttjzk5ive31ne
# 81
#
# 9ineldnhvqqdrt27evenqxgltrhgvtdnfcxcsknsgkzjzbvc
# 97
#
# 6tjkxlskvg4147evenj7even5ive
# 65
#
# 5ncdmtdhbs
# 55
#
# 9ine71nekclmqxkfdtq1ne3
# 93
#
# 8zqcsnkfnsnlhfvfpxm
# 88
#
# 6ix6ql2wo56
# 66
#
# pdpcvgsldd2wo4our6jqjfjzvd
# 26
#
# vcsvxcfdgqpp3
# 33
#
# 6ix93hree59ine9ine5ive37
# 67
#
# ztf5ive8
# 58
#
# mggphlsjczv7evenlb16ixssbdslt3hree2wo
# 72
#
# 9inedpjljc1771ne2wo
# 92
#
# 2wo74ourvstgmr3rtlztqddmnghm
# 23
#
# 2dgtpz521
# 21
#
# 19inesmsqtgz1ne
# 11
#
# ppsgns9ine9inegjvpvcnp5
# 95
#
# 9ine3hree7
# 97
#
# 312cspj
# 32
#
# 73hreephmdnmnzlfpgchqfj37fqz
# 77
#
# 57evenhqxkqfd4cqmqhsfbhtt
# 54
#
# ntzgqnj5
# 55
#
# 167
# 17
#
# xbpdhv4our5ive7
# 47
#
# 73kffl11ne2
# 72
#
# fjshmr656ixrkqbtpxqnpqgjthplnlv7dfrktxvng
# 67
#
# 8ightzjzvhp122wo8ight
# 88
#
# mgczvgctfb8tmsbtc8q2wo5
# 85
#
# jjpbkl675ivetmbc
# 65
#
# llprxv4
# 44
#
# 2wo5tvc
# 25
#
# 9ine35ive
# 95
#
# 79ine24our8ight338
# 78
#
# 6vsflc
# 66
#
# jfgx6ixzmtzjxxfc2pg71ne
# 61
#
# dhkjgnlxd6t7even3
# 63
#
# zxcsrtdsj9ine846ixjzcbsfn8ight
# 98
#
# hncmq88
# 88
#
# 2wo4our6ix19inesvlzhpgc
# 29
#
# pdktnvrqqgmpllxnmp54our9
# 59
#
# 4xckfzp
# 44
#
# xpckhm45
# 45
#
# nff1ne49
# 19
#
# 8qqthrdd712wo
# 82
#
# xksghrh71ne1ne245cvcnrfg2w1neq
# 71
#
# 5ivesmcb7
# 57
#
# mdqdktxplsqbnhz2wo3hree2wo5czjzjsztclb4
# 24
#
# 72wo39xsmsvhqfkxgxv8ight
# 78
#
# 332wo2wo9ine
# 39
#
# 6j
# 66
#
# 4dfxcvdpq13mlcds9ine
# 49
#
# 4our7kcdglrh58ightzxvrrr7even
# 47
#
# phzqhdf4our55sbd5
# 45
#
# 5vcjmvzd14our4
# 54
#
# rgp1x
# 11
#
# 4our93hree22wo8ightvzvlpgr9ine
# 49
#
# 78pkrqbdtqzhmszzf
# 78
#
# sndtjtn935ive7evenvqfffjpmz54
# 94
#
# fvz1n8ight4our853hreehmqdhbskvg4
# 14
#
# 3hree5ive27even88ight97even4our1n8ightl
# 38
#
# 73hree68ndqdk84pm
# 74
#
# gp1ne1ne7zdrzgtvbv87even
# 17
#
# 3hree7even4ndvnnkpqssfsm2rcnjbgkbtg9xp
# 39
#
# 73hree6ix7even
# 77
#
# 82wo33hree5ive3hree
# 83
#
# 2wongkzk85rt8ight5ive
# 25
#
# 479inemgtknhpqqqtk94our8ight
# 48
#
# mk24our5ive7mcqtf
# 27
#
# cqqxsqkx521ne2wot1ne8ight
# 58
#
# 3dvbblknjf9ine57even
# 37
#
# 85dntj8igh2wom
# 82
#
# 9btgrgqdkb72wo9ine42wo5sxpqr
# 95
#
# 1xlnnfxd6ix
# 16
#
# 1jvbhsf2wocdl1hklfqlpvr6
# 16
#
# 2wop2ttjfrtrdcs
# 22
#
# 385jtxlfdngz7rgj4our
# 34
#
# 4ft33hree65
# 45
#
# 74dnxqvzqp85146
# 76
#
# nhvltrljrp5ive6ix3hree1
# 51
#
# 4ourcbzbfr53hree8igh2wom
# 42
#
# nbnxzkgczj5
# 55
#
# gvcgrxfr2rnbbnsqmksrjckcg8
# 28
#
# 4our1cgrrnvt59
# 49
#
# 7evengl6ixxgnjcfst7even1ne8ight8ight9
# 79
#
# cmjbp56ixsdqbspxtbvfgxjpvb7bfsscksv
# 57
#
# 92wodzbfqscbtthzfdf3
# 93
#
# ppcs59
# 59
#
# 97even7even9vczdbphxxzmvskgqhzr
# 99
#
# 3216ixhczhdblvbsrtkfm8kmtjmqq
# 38
#
# 5ive71
# 51
#
# gkf1n8ight52wo
# 12
#
# tr96ixgntvrkjctnvhpbp9cln7even8
# 98
#
# 38ightzzktsk9ine4our6ix1nevfpnpqmdlhbp
# 31
#
# 85ive7k
# 87
#
# 73hreehxcgmh945ivejltrg
# 75
#
# 5qjtxcvbt7evendpgfrcldmkkvztbhldfgtzb
# 57
#
# 494our4
# 44
#
# gxhmbgjz9qfmmnb
# 99
#
# 2ppcfj8ight2
# 22
#
# bdjrl2wo8ight74kcrmjdbqkk1ne9ine
# 29
#
# 5ive6szxgtql9ine5ive1lbpcvg26
# 56
#
# 3bpctmgczvvzzs7gqgg44our8
# 38
#
# ssd584htkgjrd5ive
# 55
#
# 9vxbsrhmcsz96
# 96
#
# 3hree3hree24our6ix
# 36
#
# 1ne4ourqqxvjhbzck6ix9ine978ight
# 18
#
# 5ive4our3tlcfccflgkxvpksqqkc5
# 55
#
# 6ix5ive8ight2wo6ix99dbgnf
# 69
#
# 9inekzfzddjxn497even
# 97
#
# 4our74znfnkzlnpz7
# 47
#
# 77even9ine415ivevbqqqlpxcg
# 75
#
# 5ivetgr54our
# 54
#
# 2cmcn363hreeflcmzkj
# 23
#
# tvp23
# 23
#
# jz1trj5ive8ightvxslx2wo9ine4
# 14
#
# dfcvmtpstrsdzs3
# 33
#
# qpzlmnjmzzvcvq3hree8ight3hree54our
# 34
#
# 2wovsdqrp4fdtgtbdh2wo
# 22
#
# 3hreemkclqbksnj9
# 39
#
# 8ight56655ive87even1n8ightl
# 88
#
# 61nenzcz1ne9p
# 69
#
# 83hree22wondcg94our
# 84
#
# 2wox6ix6rxshtslbfh
# 26
#
# 4vpstdq2
# 42
#
# 9ine53
# 93
#
# 63hree7even9ine
# 69
#
# jdfkb28tqnjnbpfk7evenp
# 27
#
# 294ournxtfnhqss687evenzrmqdzqlk
# 27
#
# 4znzlvvfs6
# 46
#
# gv2w1ne7kqsqrvknnzsfgxzfzhx
# 27
#
# 21xpfhfjzrvtgtrkkmh95ive28ight2
# 22
#
# 9rdz6ix
# 96
#
# gnpcgr7even1ne7even95ive
# 75
#
# 51ne57even2wo7qxpgzbdtgkvtpnvclzgqqbf
# 57
#
# fkbfznkfcc94our35ive
# 95
#
# xjbngj25
# 25
#
# 8vl4our8nzftbhgxvlgskv
# 88
#
# 8ight8ightvzpxmtgnl3hree29inergj
# 89
#
# 438ight
# 48
#
# 372wo8ight8ight27even2wo
# 32
#
# 113hreerfrcqrhddqczvdc5ive
# 15
#
# 9ine5ive7
# 97
#
# 93fphqmdgrvjqjbpx1ctktzb
# 91
#
# 39inemfvthllgmb6ix
# 36
#
# 2wo3bbft7even762wonrdl
# 22
#
# 435
# 45
#
# 933hreemtfpf4856ixfzvgg
# 96
#
# 3hree57even38ight2wothzvxhr39ine
# 39
#
# qz2w1ne1679inermd1xhpft9
# 29
#
# 68ight1mstqgdvxzn7evengdtrvtp24our
# 64
#
# nbfldvhzcttk9inerhdrxpjffh85ive6
# 96
#
# 66ixjzlj3jpjbj161ne
# 61
#
# 1ne7even5ive67even
# 17
#
# 69inellfhpqgrld9ine6ix3hree
# 63
#
# 3hree53jcrc4
# 34
#
# 85ive98ightdgvhlktbvv
# 88
#
# 2vllfmpnrjjjnxmm6ix4k7even
# 27
#
# mmbdhbfqq99ine23hreebshzhdknj9
# 99
#
# hznv78sqvxnzjppq5ive7evenzskllffh
# 77
#
# 6ix5vndfv9kzc36
# 66
#
# 95ive1ne5ive382wo3
# 93
#
# fgqzjqt4qkpgstlbk
# 44
#
# 729ine5ive7even
# 77
#
# zzvhpbbllqpdpbsff87even
# 87
#
# 4jvpzjcrm8
# 48
#
# 331ne9dcppdmpcjdvssffsssb
# 39
#
# 7evensp5fjdlmpzg2wolddr6ixnlgj3hree
# 73
#
# 42wozzkckvxcfzrzctsr2woljznhpm
# 42
#
# 4our7even8lnnvbfb8lsptn7even
# 47
#
# 1znsgrrnjv28ightphktgn524our
# 14
#
# gnttqnlvmfhrlc9ine8ight2wo5ive6ixpfgfjgvckh9
# 99
#
# 3vgkzs8ight3hreemntsnthhpszrpkh1
# 31
#
# 5iveddks3hree8ightdbxvbf7even96ix
# 56
#
# trtpjjrqfc6cbsccnghp3hree4rxclfrk8ight8
# 68
#
# 1ne47evendxdr1ne
# 11
#
# 4our5mttxghdq1ne9nvdbdn3hree2wo
# 42
#
# sdtjdf5ive36ix3hreeznrv
# 53
#
# 2c37even3hree3hree2wo7
# 27
#
# hldmdhr4
# 44
#
# 6hcrdxpnpjblngks9
# 69
#
# vscjsh36ix3hree4our
# 34
#
# 3hreexsdhnkmdvdj3hree51p1ne
# 31
#
# 31nenvx53nrhnrbq2wo9ine
# 39
#
# 2won678ightppqntrtct
# 28
#
# 11nemnpcdl
# 11
#
# lrrzbxfrt565253hree3
# 53
#
# 5ive3hreevsnqxzxjdkp4nhnzsfknx61ne5ive
# 55
#
# 3hreectkjzcm86ixvbzmqq287even
# 37
#
# mjfc4gddfhszzk62wo
# 42
#
# 32wo8ightfbpcsrhlm9vkx8ight
# 38
#
# ppl1ne53hreevdvfs3hree
# 13
#
# 36ixzblcdxgrr
# 36
#
# 3mrqc8ight8thtltkg6
# 36
#
# 76ix3cjznvgv13hree
# 73
#
# tnpr16ix8ight3hree98ight
# 18
#
# 9inenjbgmznt7pkfdnrffrlhk7even
# 97
#
# 9inejn6ix63779
# 99
#
# cljvmznmjkdjs8ightjrtlrm7even49ine9
# 89
#
# 7even5ive8ightncjmffmrxcjkp58ight
# 78
#
# 99ine5ive76ix
# 96
#
# 87evendcrffrhhjbzzmh7
# 87
#
# mrc1688ightmvsnrqpkqd616ix
# 16
#
# 18ightcvcqqtdjg29
# 19
#
# znvlfrt8749ine5
# 85
#
# 7hsdnpjx4
# 74
#
# 21kvhtmvplcb21ne3hree
# 23
#
# 7nkpdjsxvkdqzjsvxmv5iveq8
# 78
#
# 6ix8ighthgtxgslkhxvnlvll29ine9inebnkffbbffsntrcvfdzmq
# 69
#
# 5ive59ine
# 59
#
# hcs1n8ightznbfz6bbslrjphkg8
# 18
#
# 4our1lfm38
# 48
#
# 2wo9inel9inexptcbs33hree2wo8ight
# 28
#
# 93923hree48ightk9
# 99
#
# 2xnhmqxcxxs5
# 25
#
# zvkfmqg2fb3rm
# 23
#
# 3cpcvjfcngk2wo
# 32
#
# gvnvbtvhvsmb772wo8ight43
# 73
#
# 3hree19nlcq
# 39
#
# jshvrzz7even8c2snfm9ineqnbdlbr
# 79
#
# bvvttclxpqt2wofrkp3hree67even
# 27
#
# 9inevj9ine7
# 97
#
# 5iveqhczdqzl47even
# 57
#
# 84tvhrrtt5
# 85
#
# 4our3hreecmrvf1nevsrsklqrrzpdp5
# 45
#
# knnmdlrk53hreedzhdxjt7even3djbnqtfjg
# 53
#
# qbjkkslhb2
# 22
#
# 2wo254our6ix14our5
# 25
#
# 8pbkqrmtzvzbptvj7nkdsvcpg
# 87
#
# k17evenzdzbnsjscp9ine2zcfhjqdtvmjnpn6ix
# 16
#
# 7rjsfmz39ctpkgnm
# 79
#
# 45ivekjcmlxq8ight5ive89inelszhv
# 49
#
# jsbjcvfcvlxs162wollkphts3
# 13
#
# 8klnmls1ne6ix7
# 87
#
# lzmqtzp56ix
# 56
#
# 1ne73hree
# 13
#
# 3sz3hreesj8ight143hree
# 33
#
# cnq37even978ightcvvbkdzb5ive2
# 32
#
# j5ive724our7
# 57
#
# 9ineqgpbdzjqfd5nvcgcm69
# 99
#
# jfjtrrhcgzgqgtdmdsc3hree83hree8ight3hreekvztcfnnxp
# 33
#
# xxfjjhvrdp2wo1ne9inebjlsgssmpsvv2wo12wo
# 22
#
# 4ourz9ccjjxzmqmhm61
# 41
#
# 7evenfzf4our5ivehrpjtrvglprdg4cxtcjgc
# 74
#
# 2cp5zbl
# 25
#
# czhndkczznnftdh79ine
# 79
#
# lczpbbjnh14ourxbskj
# 14
#
# 57evenc31ne
# 51
#
# 18ightnqbmkhjzzxqsxn5767even
# 17
#
# kcxhmcnn1ne2wondzthz653hree
# 13
#
# 4our8ight5iveczzdxgdvfc67evensrnbvhftl
# 47
#
# 6ix34our4our4our5ive
# 65
#
# jtmrqj1ne7even3hreedmfpv11ne8ight2
# 12
#
# 6bslvklq4our92wo4our
# 64
#
# 3hree5ive3
# 33
#
# hqjhndlzlmdtkkhlblvxs26vsnpkfjgn513hree
# 23
#
# l2863hreerhscjbqts
# 23
#
# 859gmvdrqbbr2
# 82
#
# 7481ne7even1ne
# 71
#
# 95ive2wovlmdgggvss
# 92
#
# 2mmrxstxqb2wo2wo8ight7
# 27
#
# 18ightsrhkz1ne
# 11
#
# svjzgxrvcfjxp54our8ight5ivejlbtlm9ine
# 59
#
# 269ine7pph6h
# 26
#
# lprdrpvs234our82wo7even
# 27
#
# 5ivendxhlxvrmtlkmjf59ine3
# 53
#
# jpcnzt65ive1netzdbmxzzrnxblb7tmvmb9ine
# 69
#
# 7even3hree62
# 72
#
# 81ne5gxljlhzgb94ourfjcmb6ix
# 86
#
# 5ive78891nerkdxrlgrbqpb
# 51
#
# tlkkzfqp8ight11nelvbbztlchhtrfjbdm
# 81
#
# j8igh2wo761ne
# 81
#
# kdtxdv923217even9jhczcl
# 99
#
# 12cmjczrskprx9
# 19
#
# mmf5ive338ightgzczrhxpngn6ixzztlrx
# 56
#
# pcxlcnmqr57evenjqt5mgbgjjcp8ightzdrzgnfrbjbcgc
# 58
#
# 633bdkqk
# 63
#
# mfxfslmms86ix4our565
# 85
#
# 245ive7evenmkprgbxlvzsnmn
# 27
#
# cqf81ne
# 81
#
# 73hree86ix
# 76
#
# 97evenpgcfrnvzzmll751ne46
# 96
#
# 18ightcbprgf
# 18
#
# 7even5ive1sjzlnlvcksnqzlhc
# 71
#
# 2wo35ive5ive1ne7even1neckfcrld5
# 25
#
# 3hreekxzfcxzjpfz92mltnrnn2wobzhzgcg
# 32
#
# 55ivexjsqskhdx293hree267
# 57
#
# 9ine238ktdrmpkh4ourbl
# 94
#
# 9f
# 99
#
# vxstggkg747
# 77
#
# 7evenjkpsmkzjrtrhcd99
# 79
#
# g4our96gxpchmkz
# 46
#
# 56ix42lvxfbc
# 52
#
# 3hree2wo3hreecck343hree
# 33
#
# 25ive7
# 27
#
# 5ivecgxqrcbd3hree9hxbkkzsfpm7
# 57
#
# 8ightgjftmm6ix3
# 83
#
# 8ighttjfpxbplxm35rrbppjfjsts
# 85
#
# 91ne3db
# 93
#
# 4nz746ix68dpfk3hree
# 43
#
# 4our45ive
# 45
#
# 34ourcngqmpkdtmnvfb7even4ourl
# 34
#
# slvb13
# 13
#
# 67even1ne
# 61
#
# 8ightg4qvrdkjhsbn
# 84
#
# 3hree18ight3hree6ix5ive9inesqczjcm
# 39
#
# jtnddjsbc7even3hree9ine29inedvblpcl
# 79
#
# ppffnzsbmnzctdjqttrxz8ightz13hree
# 83
#
# 7r
# 77
#
# vhksnh9296ix2wobfdtmrfxbn9inegtxkrnl
# 99
#
# zf1n8ight1
# 11
#
# 96ix123vcjjz
# 93
#
# 99vknnqszvvm7
# 97
#
# 3hree4our1fsxgqvcs2
# 32
#
# 4ourmssjszkkz14our62wo8fhfgbkkkx5ive
# 45
#
# 43hree37bx8lgkvgvjjpxzcmfvn
# 48
#
# 2wotlxxhm64our499n
# 29
#
# 7xckrffbmzf757even5ive34our
# 74
#
# 29inetljfcpnrzkh7431n8ightlgc
# 28
#
# 58ightx9ine3hree8ight4
# 54
#
# 563hree4our9ine
# 59
#
# thfc37fksgkkkn4our29ine
# 39
#
# 4jtbckvmqc
# 44
#
# 1534
# 14
#
# 3hreexcc84ourmtvkqdchjx
# 34
#
# 3sthrzbjbxpcsdhjmfjztbgknrpb
# 33
#
# 15ivextcmx96ix
# 16
#
# 1ne639lkj5ive
# 15
#
# 2wovlxkxbqrjs61ne1mctzqzx
# 21
#
# n4our1ckrgnz
# 41
#
# 4our1jsmdn
# 41
#
# 615
# 65
#
# 2wo64ourgqqz
# 24
#
# fqcmkbhjfn2wo5ive9ineqhqss1nessvmc72
# 22
#
# 67even8ight5rsftxhhnknjj
# 65
#
# 3hree7even5ive8ightntjgpkxbmkqxhstdq6gjbzxqjsmm4
# 34
#
# qxnslq294gddrlkvdxqdqkcghfbg7even1
# 21
#
# ntdvbndqqvmhtrzvvcdlqz1
# 11
#
# lxkbqjc7even88ight7evenddzq7evenjst
# 77
#
# 11vlvklqqgsxhxng7even7kljlpj5ive3
# 13
#
# 17zxn
# 17
#
# 3hree8ight8ight9
# 39
#
# 1nemzdc76ix
# 16
#
# 13dttxqnfdv3jhc2wo
# 12
#
# 7jxhhlxfsxzkqz2wo17evenc
# 77
#
# thmbtqqmtfzfnftqbsxm68ightmhf5ive7
# 67
#
# 9ine1nebd5dfzqfpsx4our2
# 92
#
# 41nevszfmdxmcrzmpcks6ix3hree3hreedt
# 43
#
# 5k8ight7
# 57
#
# 2wo9hjbcgdm1ne
# 21
#
# 9ine4qsf
# 94
#
# s2w1ne9ine5ivexszrjm827even
# 27
#
# 92krc6ix7evenznqcbdvpntbjzcbm42wo
# 92
#
# 4our4ourhq8ight9rbrtljfgq6ix5iveflslbbxxh8igh2wobhv
# 42
#
# 3hree8177even4tstspnczk8ight
# 38
#
# 7nfd9
# 79
#
# 3hreezngvkmj7mvksmsvjxj5ive8ight
# 38
#
# 9x9inepctct7even7evenqqqddldd3
# 93
#
# kdbx6ix798fvsrhvxm2wolmxpxcm8
# 68
#
# 1ne4our9ine7
# 17
#
# nch9ine6gtszxkhtsvzjcnmlq9inevkkrvv
# 99
#
# 8sh2wop8ightgbzmbbdnrtpmrl
# 88
#
# 856ixhb4our4rldcdnqn8ight
# 88
#
# xbjhhjbk4148bmsvjz819
# 49
#
# 7qqvmxlqzqlmrr
# 77
#
# 1ne9144our5ive
# 15
#
# 8ight723hreenfmbfnxdhkmgjkrmsc
# 83
#
# 8ight576ixvmfjprpm
# 86
#
# 8fpfkxffqzp8
# 88
#
# 95hbbl29
# 99
#
# pzvhmkdgqp1dhsrlv78bmvhdqfcgcpdtgtpmmlnmk5ive
# 15
#
# 161ne6ixb68dzz
# 18
#
# 7even9inenvmbjknplx7even57sfghptmq75
# 75
#
# xxz2w1ne6ix1ne4gczrnpzrsfqqlz7even17
# 27
#
# xn5ive94ourl5ive162
# 52
#
# 5ivercg3qkgdxpdxcp1ne
# 51
#
# 6ixdqkhhht46ghvd814
# 64
#
# zvpdmfvgxl459ine
# 49
#
# 74our4bmjssxznnmgtlqhptcb5ive
# 75
#
# 4our49nlkpfxjc9ine81
# 41
#
# zdgtfqszsctjtvr7qqhvs9ine7evenxtcmdhfzxvfrtjqhzmm6
# 76
#
# 54our2gmgmvzkvgknfpx5ive
# 55
#
# 22wo1
# 21
#
# 478ight96k8ight3hree
# 43
#
# 7cb
# 77
#
# 8ightdzzjjknbxv5
# 85
#
# dsmg4our7evengp4
# 44
#
# 55ive3hree8ight6ixxqnrsfxxmjckfzhddhszqvdjr
# 56
#
# 3jpsrxlv9ine4our7gtjvk
# 37
#
# bfdtkgfhlnkhdrpfg3
# 33
#
# qhzdz6ix61ne91ne
# 61
#
# 4our75qsbtrb9mhhhhnbl
# 49
#
# s8ighthgddd2759ine8ighth
# 88
#
# 9inemg6ixrkmhdpjtzg5ive91
# 91
#
# 89ine2wop8ightsz9
# 89
#
# 3hree427c58ight
# 38
#
# 36ix1ne9ine4our6qksfflsvhk21
# 31
#
# 81nex76vmhxm
# 86
#
# 7evenkrvrd5ived46ix6
# 76
#
# rzqrxmq21
# 21
#
# 75gszfc8vrj8
# 78
#
# hdgclvmgg332wo
# 32
#
# 1dv8rvdxbfjclr
# 18
#
# grrhj3hree95iverhqt
# 35
#
# 6nvtzl6shxrlbmrqck7even44our
# 64
#
# 4our8ight47evenks6ixhdvvbszkc8ight6ix
# 46
#
# 4oursctcndrchdb4our2wozpdkjc3vqv
# 43
#
# 8741ne3hree6ixtblzsnrrdvqmpgpfb
# 86
#
# 1pgmgczsgngx
# 11
#
# 475
# 45
#
# 2jkfphlzqhz
# 22
#
# 4576
# 46
#
# 1negnbrs8ightptrgdfkbqdcv2wo1qbxj
# 11
#
# 43hreeznd
# 43
#
# 82wo21
# 81
#
# 79ine8
# 78
#
# 37even2dbrzxbfvg4
# 34
#
# 49378ightctmzkxkkzr
# 48
#
# 5mtccqv23hree1netpggmmzbhlvkt
# 51
#
# qpjvmgqxcj26ix8ight
# 28
#
# ttmz2wozrfqhfhgkp6pltknxmcfqngh
# 26
#
# 1negnztn96ix
# 16
#
# 6ngsnzbfvvt1ne274our6ix2bqhbkgkr
# 62
#
# 1nejnplq3
# 13
#
# hml2wo5ive4ourvjkkdjjksbdksqtnr2trxnkltgp
# 22
#
# 1ne94our5mvgjgjn8ight
# 18
#
# 358hx4our2
# 32
#
# bsmgfvnt7jlsrdvbq
# 77
#
# 6ix1ne1ne53hree8nvp7zthbv
# 67
#
# jmfpnrmr9ine7evengsqggg7
# 97
#
# mkvgjdjhv7even1ne88ight1n8ightdhq
# 78
#
# 3hreeccljpjh3hree2wo6923znj
# 33
#
# 1pjkbks61ne35ffj
# 15
#
# ctpdddkxtstvzcgbfdfspbl1ne1ne3hreekvsltblvhx4
# 14
#
# 9ine6zmzkjlpc6ixsqt7gkbdhjqn3hree
# 93
#
# 2wo5ive17evenkrnfbfjpdj1ftz9
# 29
#
# mhfdxzqlgjfvfxvm7
# 77
#
# 1rhznqnpgkqbtprvbb
# 11
#
# rhxskjqrt21nemppcsktz6
# 26
#
# jhxsrxzggg5ive2wo4our7even9
# 59
#
# 8ightnjzddrjppq512w1nebtl
# 81
#
# 21ne6ix1nehlfmxkjpfxpkfkhbkjhcvjct5ive8
# 28
#
# zv93hree6djkfn6
# 96
#
# smx8
# 88
#
# fdrx8ightj73hree6dflczzmgdr
# 86
#
# zvzrb52wo6ix2wo
# 52
#
# 9931ne7even57even
# 97
#
# 9189ine2wo2wo9ine5ive6ix
# 96
#
# 1ljpljm9ine5ive9ine78igh2wolsn
# 12
#
# 5bphjdgk2wo7even4
# 54
#
# 7even86ix
# 76
#
# mjstvsjrltx37evenkddd
# 37
#
# kljfvvmxkrkcctjpnmrv8ight76ix
# 86
#
# 9ine8ight14dkkcsvg417even
# 97
#
# dvxbzxxks1nefjgfppsd18ight
# 18
#
# 6ix3hreeqfb1ne85ive929
# 69
#
# sgktnmjj7even5
# 75
#
# 442
# 42
#
# jbp2worxzzmkhmszn19ine4our9
# 29
#
# lcfpbvkkgnggtkh83hree1ne4ourtsvrrkcnvdpm
# 84
#
# 818ighthgr
# 88
#
# jhklkvm6vqpvjdsh
# 66
#
# lcgjdkm5578kn9inezsdcp7
# 57
#
# 6ix9ine8ight4
# 64
#
# qdlpnqm7mbtgbvqznt8ight6fz9inecrrgqsq
# 79
#
# tdmj4our4our85ive7even8ight
# 48
#
# 1gds3hree
# 13
#
# 3hree9ine421nezctqjj81ne
# 31
#
# ft4our1ne21nephv5
# 45
#
# nb2w1nexjpnqtlck5pxmfzbvp558ight4ourbxzxrrstp
# 24
#
# 6ix9ine2mpcldclfvklh5kmggqbtbk
# 65
#
# 13hree4chsjrknhd2woxqjcgssnq
# 12
#
# dcpjkkr3hreeqpncsbfpmhtmtfvzjzmps8cltmhqzl4
# 34
#
# 29inelr3hree3hreerzxqhdpcmf3hree6ix
# 26
#
# 5nfsrrh17evenlcnrblxjhjsmdndp3hreevjphjqlznd
# 53
#
# 86kdqz8fhsxfkxvds8ightmsrtrrc3
# 83
#
# 1pmpzsjdqnm78ightfrzxtbxkdkdbzbxqlhg
# 18
#
# crpxx2wo7cck
# 27
#
# 19hjngzt
# 19
#
# 588ight32wo2wo1pqr
# 51
#
# 1negmc33hree7
# 17
#
# 8ightzbchgxsdpq5ivejf38igh2woflt
# 82
#
# n9ine9inetkffffblk1ne7even66
# 96
#
# cg8igh2wod3hree9pqkmkbbpvn3hree8ight
# 88
#
# svjhcngvlksz4dnvfg
# 44
#
# 2wo6ixt5ive7
# 27
#
# cf1ne93hreemhvbpqrbbklfvr8ight6
# 16
#
# 8ighttmltbk3hgtrtb
# 83
#
# 2wo6t219ineslqmt65ive
# 25
#
# df1n8ight9inegrxcgjmjdqlpdjskllzpltq2jg6ix4
# 14
#
# 693hree4ourkqfzdpvtbxqpk2wo6
# 66
#
# 7even8ight644our7
# 77
#
# 726ix4ntdhcphx482w1nedbn
# 71
#
# tbbcskrmmj4
# 44
#
# xq93hree28
# 98
#
# scq9qbtzp
# 99
#
# 4our4ccftsmnxpj951ne43hree1ne
# 41
#
# gvs286jvskvvzlhc6
# 26
#
# nspgkhf119fdcqjtzmlqqz
# 19
#
# 8ight1zqp
# 81
#
# 6979ine9ine4
# 64
#
# 5jnnsgrhnmjmttbkql8
# 58
#
# 7even8ight51ne6ix9btbclcrrpz3hree
# 73
#
# 118ight5383
# 13
#
# 9321ddslmdlb51nefgdmz
# 91
#
# 392wozhclzjfjg7even9
# 39
#
# 8ight6tqvrfmkxmhldbvv
# 86
#
# 2wogrldddksg17even8
# 28
#
# 7even22dgjzqdlmmfvtxnnglqxbgfhgvglrg1
# 71
#
# 1ner676pkkm9inegff
# 19
#
# 3lvkx5ive15qthp5ive3hree
# 33
#
# 5ive7even3hree2llxsgz8ight
# 58
#
# 4our3jftmvmqzql8nscjvph17even3hree5
# 45
#
# 4chjvr9ine4our
# 44
#
# 49ine9ine46
# 46
#
# 7even9ine7cgdnx
# 77
#
# 7mfqtmpb9ine
# 79
#
# 383hree5ivebjjpgj
# 35
#
# kn4lpfd14our
# 44
#
# 9ine89krvcbcvqn
# 99
#
# 24our62
# 22
#
# 81nehrrhxpmlpnfqtlxmfzps
# 81
#
# vz1n8ight2gkpfczjmht5zlfxmnkjfq
# 15
#
# mpd1ne5
# 15
#
# nv39ine2wo
# 32
#
# mt8igh2wot46ix5ive5ive23hree6ix9
# 89
#
# ht2w1ne23hree5ive1ne3
# 23
#
# 1ne9kphlcks4ournrkxktxvz9bkfnq
# 19
#
# 4our6ix1ne8
# 48
#
# 66crcj1ne2wo
# 62
#
# bcrsltzkd648ightcjzmc2wo7even
# 67
#
# rplxlbpddn8ightvqdclxqqlh3hlkhkgrfvl9ine
# 89
#
# 6ixdjdhcvvnnccp7evenkhvqp1
# 61
#
# qj7even9ine8ight73hree74our
# 74
#
# 3hree51ne2pzgbnmj1
# 31
#
# 2kbbhjm7even464
# 24
#
# 8ight7even3hree31nevkmhmjvcd
# 81
#
# 2rxdcjpzkph
# 22
#
# 2wo97evenpbhcbklcpn6ix3hree
# 23
#
# 7even97even6ix4zklllpckrxrcpctlgt
# 74
#
# 55ive5iven6
# 56
#
# 2fjf5ive6ixg8ight3hree
# 23
#
# 7even4pp5tpmc4our1ne
# 71
#
# kftkjnhnms5hbngpqhxc1ne
# 51
#
# 1dnrr7even7even
# 17
#
# fhjcmxvpbsr99
# 99
#
# 7even413hreeckvp
# 73
#
# 152wo3hree
# 13
#
# 5292wo
# 52
#
# xhtmrmdzkg7evenfkkzmqpg1neqqzdhpbd8ight9
# 79
#
# ttnzmptlskm5pzvdnc15sqqcmmvx4
# 54
#
# 7ndb
# 77
#
# 55bxxpvjhkqd6ix4our
# 54
#
# 142wochvtxrdcslbsrggcxvjpg
# 12
#
# 27even3hree
# 23
#
# 9cgfnrxprbz29inejrhbgsczrhlxn6
# 96
#
# tfljdjcpltgzhmxv9
# 99
#
# 71ctrzxbkhhqpgc
# 71
#
# 2wo13hree8ightrskmzsmzhcdbxp2pztmgcg
# 22
#
# 78ight6934
# 74
#
# 5ive7lgspjnhrsmvm8igh2wolj
# 52
#
# vtqcrtjmtkmvvnmm9ine1ne87kclsrqrf
# 97
#
# 55ivetslmr1nefdsdxr
# 51
#
# 7even88
# 78
#
# gsvbn94our2wo4zth5ive
# 95
#
# nqkgjlqgqbng5rxzbkhzmzcgkrsblfnqstxlcg
# 55
#
# 9znzctbdf2wo9ine1ne
# 91
#
# mrngnmkdjv487evenvprcvllqq1ne
# 41
#
# 9inecxctvm54our621blbfctsg2
# 92
#
# 7even63hreehzhbmb3hree2
# 72
#
# 35ive3hree
# 33
#
# sfsncqnp342woxdm9inenqqhd4our
# 34
#
# 4our7gbcslngdx385lhkslcjhq5qjmvchc
# 45
#
# 5ive4hnnkk314our
# 54
#
# 73hree85ive3hree71ne3hree
# 73
#
# sjqpktfsn3tdjflb2
# 32
#
# 19inegn1ne
# 11
#
# rvgcmzhffrntqqnhjxtxqrmvbsrt8ight34
# 84
#
# 7slcmpmvhfhpzgllr5ktnzm71nevznhnnbrcc
# 71
#
# 2694our1bzjrmh8ight3fgcr
# 23
#
# 97even3hree4ourzlqgjnrmq7xcmntjncnt6ixthlgq
# 96
#
# 7even8ight19fbphndppb82w1nebbj
# 71
#
# 8ightxblvnvrtpsmcngtbtl2wo6h8ightprccv
# 88
#
# 6ix8ight6ix32
# 62
#
# 496ix72wo9ine25ive
# 45
#
# 255ive5
# 25
#
# 421ne2wonbl
# 42
#
# kbhrtpgnp6
# 66
#
# nsfktqkbzdcmgf28
# 28
#
# b2wo8ight9829ine
# 29
#
# cpcrbqzmkbtcjmn586ix
# 56
#
# 1ne3hlgmgphkcnp
# 13
#
# 74zpbzmxc
# 74
#
# 8ight7even7even36gdcnmrxn6vhvkmc5
# 85
#
# 19ine9inehkr6ix
# 16
#
# 3hreeql1ne7even1
# 31
#
# 8ighthhq9cbptsljhz7evenhzpxm
# 87
#
# 81ne1nebdthldf68ight3hree
# 83
#
# 71nefxlhzxcmhc45ive88ightjlcms
# 78
#
# 48skgslmflkhnpqt6ix
# 46
#
# rgrdzx47even5ive
# 45
#
# 1nefxfxhslc9hjxkdqjs63hree9ine
# 19
#
# 5ive7even1ne3hree2sjnvt5
# 55
#
# 925ivel83
# 93
#
# 3hree25ivenlbtvsmv6ix
# 36
#
# 3hree5ive89ine
# 39
#
# mjnch2wosdbh72923hree
# 23
#
# hdqffz7even37evencqv
# 77
#
# 73xcqzdt7jvkkskpg9ine5
# 75
#
# 23hree9inessgntvctkns2kqmcqdvjt
# 22
#
# dktgqszxcptlpxpzl6ix81ne2woqlxk
# 62
#
# pbvvfjlzb7even2
# 72
#
# qtlfxzplrrcjfr69ine
# 69
#
# 7gs3hreeplhxbbmrht9ine53rxpjghgjq
# 73
#
# 2bmmjrzzjnz9dfplppnjmktzc6ixrpqxcptskjkfqxgx
# 26
#
# 5ivedrtnxnjqxnt2qtbvlj
# 52
#
# j889inelnjlsnzsqk31rg
# 81
#
# hcfxflqvkvdfmthkjdpfzzlzzh4kdmmhvspzdd5ive3hree
# 43
#
# 5qsl
# 55
#
# 98ight36ixxvjktfzbpglmz4our37
# 97
#
# 46ix2
# 42
#
# zqrlljp2wo1ne5knbhf726ix6
# 26
#
# 5k65blpldztzjh7sghcsdnpm8
# 58
#
# 6ix48
# 68
#
# skdpdfqtglzvlpqxp32w1nelcr
# 31
#
# 2woklhnd7even6jdhcsccjgp682w1nelb
# 21
#
# 764our79ine8ight
# 78
#
# gn2woc595ive7even9ine4our
# 24
#
# 19ine647even8
# 18
#
# 7even49264our
# 74
#
# 31gsjtkjdvjdqnrsgnpbnxsdrzmtskfdqhd
# 31
#
# 7even829inetfnxhlx8ightbt9
# 79
#
# xttqntsdmv4our82wo
# 42
#
# zbjb8ightfhbhcfkbhrthqhg6ix3hree115ive
# 85
#
# 56ixpfnpmcpfppxvsfprxfbfc7even4our
# 54
#
# 254our3hreexgvhzdkzfh
# 23
#
# 4xdpdpkldnb1ne
# 41
#
# 987evendhjzlddn59ine2wobrfmbshn
# 92
#
# 77832wo9ine8ight
# 78
#
# 14our4our
# 14
#
# 44ourztn3hree1ne8mqmd4our
# 44
#
# fbfvqgvqf1ne5nctdcdpt8ight2wo
# 12
#
# dhfbh1ne44ourlgzftg
# 14
# 53389
